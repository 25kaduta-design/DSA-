# %%
string="hello world"
result=''
for ch in string:
  if ch!=" ":
      result+=ch
print (result)
# Out:
# helloworld

# %%
String ="this is a sentence."
words=string.split()
count=len(words)
print(count)
# Out:
# 2

# %%
l1=[1,3,5]
l2=[2,4,6]
l1.extend(l2)
print(l1)
# Out:
# [1, 3, 5, 2, 4, 6]

# %%
l1=[1,3,5]
l2=[2,4,7]
merged =l1+l2
merged.sort()
print(merged)
# Out:
# [1, 2, 3, 4, 5, 7]
