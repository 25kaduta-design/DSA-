# %%
no=int(input("enter no:"))
res=no%10
print(res)
# Out:
# enter no:263
# 3

# %%
no=int(input("enter no:"))
n1=no%10
n2=no//10
res=n1+n2
print(res)
# Out:
# enter no:25
# 7

# %%
no=int(input("enter no:"))
n1=no%10
no=no//10
n2=no%10
no=no//10
n3=no%10
rev=n1*100+n2*10+n3*1
print(rev)
# Out:
# enter no:263
# 362

# %%
no=int(input("enter no:"))
n1=no%10
no=no//10
n2=no%10
no=no//10
n3=no%10
no=no//10
n4=no%10
no=no//10
n5=no%10
rev=n1*10000+n2*100+n3*10+n4*1
print(rev)
# Out:
# enter no:26073
# 30706

# %%
no=int(input("Enter the no:"))
rev=0
while no>0:
  rem=no%10
  rev=rev*10+rem
  no=no//10
  print(rev)
# Out:
# Enter the no:2502
# 2
# 20
# 205
# 2052

# %%
no=int(input("Enter the no:"))
count=0
while no>0:
  no=no//10
  count=count+1
print(count)
# Out:
# Enter the no:542
# 3

# %%
no=int(input("Enter the no:"))
sum=0
while no>0:
      rem=no%10
      sum=sum+rem
       rem=no//10
print(sum)
# Out:
#   File "/tmp/ipykernel_24759/1010407229.py", line 6
#     rem=no//10
#     ^
# IndentationError: unexpected indent

# %%
no=int(input("Enter no:"))
fact=1
while no>0:
    fact=fact*no
    no=no-1
print(fact)
# Out:
# Enter no:5
# 120

# %%
no=int(input("Enter the no:"))
rev=0
save=no
while no>0:
  rem=no%10
  rev=rev*10+rem
  no=no//10

if rev==save:
    print("no is palindrome")
else:
    print("no is not palindrom")
# Out:
# Enter the no:1234
# no is not palindrom

# %%
no=int(input("Enter the no:"))
sum=0
save=no
count=0
while no>0:
  no=no//10
  count=count+1
print(count)
no=save
while no>0:
  rem=no%10
  sum=sum+rem**count
# Out:
# Enter the no:153
# 3
# no is armstrong

# %%
for i in range(1,10001):
 no=i
sum=0
save=no
count=0
while no>0:
  no=no//10
  count=count+1
no=save
while no>0:
  rem=no%10
  sum=sum+rem**count
  no=no//10

  if sum==save:
    print("no is armstrong",i)

# %%
no=int(input("Enter no:"))
save=no
sum=0
fact=1

while no>0:
  rem=no%10
  fact=1
  while rem>0:
     fact=fact*rem
     rem=rem-1
  sum=sum+fact
  no=no//10

if save==sum:
  print("no is peterson")
else:
  print("no is not peterson")
# Out:
# Enter no:145
# no is peterson

# %%
no=5
if no%2==0:
  print(no,"is even")
else:
  print(no,"is odd")
# Out:
# 5 is odd

# %%
per=75
if per>=40 and per<=60:
  print("take admission i xyz college")
elif per>=61 and per<=80:
  print("take admission in a college")
elif per>=81 and per<=100:
  print("take admission in B college")
# Out:
# take admission in a college

# %%
cp=int(input("enter cost price:"))
st=input("are you student Y/N")
if st=="Y" and cp>500:
  print(cp*0.10)
else:
   ds=(cp*0.05)
    else:
    if cp>500:
      ds=(cp*0.08)
      else:
        ds=(cp*0.02)
          net=cp-ds
          print(net)
# Out:
#   File "/tmp/ipykernel_1748/1441513164.py", line 7
#     else:
#     ^
# IndentationError: unexpected indent

# %%
for i in range(10,0,-4):
  print(i)
# Out:
# 10
# 6
# 2

# %%
arr=[1,2,3,4,5,5,6]
for i in range(len(arr)):
  print(arr[i])
# Out:
# 1
# 2
# 3
# 4
# 5
# 5
# 6

# %%
arr=[1,2,3,4,5,]
for i in range(len(arr)):
  print(arr[i])
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range (1,11):
  if i==5:
    break
  print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
i=1
j=10
while i<=10:
  if i==3:
    i=i+1
    j=j-1
    continue
  print(i,"t",j)
  i=i+1
  j=j-1
# Out:
# 1 t 10
# 2 t 9
# 4 t 7
# 5 t 6
# 6 t 5
# 7 t 4
# 8 t 3
# 9 t 2
# 10 t 1

# %%
ls=[]
print(type(ls))
# Out:
# <class 'list'>

# %%
ls=[1,2,34,32,22]
print(ls)
for i in range(len(arr)):
  print(arr[i],end=" ")

  print()

  for x in arr:
    print(x,end="")
# Out:
# [1, 2, 34, 32, 22]
# 1
# 123452
# 123453
# 123454
# 123455
# 12345

# %%
arr=[11,22,33,44,55,66,77,88]
print(arr[3])
print(arr[-2])
print()
# Out:
# 44
# 77

# %%
arr=[11,22,33,44,55,66,77,88]
print(arr[1:5])
print(arr[ :5])
print(arr[::2])
print(arr[::-1])
print(arr[::-2])
print(arr[2:7])
# Out:
# [22, 33, 44, 55]
# [11, 22, 33, 44, 55]
# [11, 33, 55, 77]
# [88, 77, 66, 55, 44, 33, 22, 11]
# [88, 66, 44, 22]
# [33, 44, 55, 66, 77]

# %%
arr=[5,3,9,2,1,8]
max_val = arr[0]

if arr[1] > max_val:
    max_val = arr[1]

if arr[2] > max_val:
    max_val = arr[2]

if arr[3] > max_val:
    max_val = arr[3]

if arr[4] > max_val:
    max_val = arr[4]

if arr[5] > max_val:
    max_val = arr[5]

print(f"The maximum value is: {max_val}")
# Out:
# The maximum value is: 9

# %%
arr=[5,3,9,2,8]
min_val = arr[0]

if arr[1] < min_val:
    min_val = arr[1]

if arr[2] < min_val:
    min_val = arr[2]

if arr[3] < min_val:
    min_val = arr[3]

if arr[4] < min_val:
    min_val = arr[4]

if arr[5] < min_val:
    min_val = arr[5]
    print("the minimum value is:")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1748/3597935378.py in <cell line: 0>()
#      14     min_val = arr[4]
#      15
# ---> 16 if arr[5] < min_val:
#      17     min_val = arr[5]
#
# IndexError: list index out of range

# %%
arr=[5,8,9,10,2]
max=arr[0]
min=arr[0]
for i in range(1,len(arr)):
  if max<arr[i]:
     max=arr[i]

# %%
arr=[3,2,3,1,2,4]
ans=[]
for x in arr:
  if x not in ans:
    ans.append(x)
print(ans)
# Out:
# [3, 2, 1, 4]
